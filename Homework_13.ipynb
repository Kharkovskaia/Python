# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
# ### Обязательная часть
# Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# KEYWORDS = ['python', 'парсинг']
#
# Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: <дата> - <заголовок> - <ссылка>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
URL = 'https://habr.com/ru/search/'
params = {
    'q': ['python', 'парсинг'],
}

# %%
res = requests.get(URL, params)
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru" class="no-js">\n  <head>\n    <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n<meta content=\'width=1024\' name=\'viewport\'>\n<title>Результаты поиска по запросу «парсинг» / Хабр</title>\n\n\n\n\n\n<meta name=\'yandex-verification\' content=\'71593b225aeafc4e\' />\n<meta name=\'referrer\' content=\'unsafe-url\' />\n<meta name="pocket-site-verification" content="ed24b2b9721edf0a282c5b4a3232c4" />\n<meta name="biu" content="https://dr.habracdn.net/habr/6001a5d9/images/">\n\n<style type="text/css">\n  @font-face{font-family:\'Fira Sans\';font-style:normal;font-weight:500;src:url(https://dr.habracdn.net/habr/6001a5d9/fonts/FiraSans/firaSans-medium.eot);src:local("Fira Sans Medium"),local("FiraSans-Medium"),url(https://dr.habracdn.net/habr/6001a5d9/fonts/FiraSans/firaSans-medium.eot?#iefix) format("embedded-opentype"),url(https://dr.habracdn.net/habr/6001a5d9/fonts/FiraSans/firaSans-medium.woff2) format("woff2"),url(https://dr.habracdn.net/habr/6001a5d9/fonts/FiraSans/firaSans-medium.woff) format("woff"),url(https://dr.habracdn.net/habr/6001a5d9/fonts/FiraSans/firaSans-medium.ttf) format("truetype")}\n</style>\n\n<link href="https://dr.habracdn.net/habr/6001a5d9/styles/main.bundle.css" rel="stylesheet" media="all" />\n\n\n\n\n\n<meta name=\'yandex-verification\' content=\'67d46b975fa41645\' />\n\n<link rel="apple-touch-icon" sizes="180x180" href="https://dr.habracdn.net/habr/6001a5d9/images/apple-touch-icon.png">\n<link rel="icon" type="image/png" sizes="32x32" href="https://dr.habracdn.net/habr/6001a5d9/images/favicon-32x32.png">\n<link rel="icon" type="image/png" sizes="16x16" href="https://dr.habracdn.net/habr/6001a5d9/images/favicon-16x16.png">\n<link rel="manifest" href="https://dr.habracdn.net/habr/6001a5d9/site.webmanifest">\n<link rel="mask-icon" href="https://dr.habracdn.net/habr/6001a5d9/images/safari-pinned-tab.svg" color="#77a2b6">\n<meta name="application-name" content="Хабр"/>\n<meta name="msapplication-TileColor" content="#77a2b6">\n<meta name="theme-color" content="#77a2b6">\n\n\n  <link title="Результаты поиска по запросу «парсинг»" type="application/rss+xml" rel="alternate" href="https://habr.com/ru/rss/search/?q=%D0%BF%D0%B0%D1%80%D1%81%D0%B8%D0%BD%D0%B3&order_by=relevance&target_type=posts&hl=ru&fl=ru"/>\n\n<script>/* Font Face Observer v2.0.13 - © Bram Stein. License: BSD-3-Clause */(function(){\'use strict\';var f,g=[];function l(a){g.push(a);1==g.length&&f()}function m(){for(;g.length;)g[0](),g.shift()}f=function(){setTimeout(m)};function n(a){this.a=p;this.b=void 0;this.f=[];var b=this;try{a(function(a){q(b,a)},function(a){r(b,a)})}catch(c){r(b,c)}}var p=2;function t(a){return new n(function(b,c){c(a)})}function u(a){return new n(function(b){b(a)})}function q(a,b){if(a.a==p){if(b==a)throw new TypeError;var c=!1;try{var d=b&&b.then;if(null!=b&&"object"==typeof b&&"function"==typeof d){d.call(b,function(b){c||q(a,b);c=!0},function(b){c||r(a,b);c=!0});return}}catch(e){c||r(a,e);return}a.a=0;a.b=b;v(a)}}\nfunction r(a,b){if(a.a==p){if(b==a)throw new TypeError;a.a=1;a.b=b;v(a)}}function v(a){l(function(){if(a.a!=p)for(;a.f.length;){var b=a.f.shift(),c=b[0],d=b[1],e=b[2],b=b[3];try{0==a.a?"function"==typeof c?e(c.call(void 0,a.b)):e(a.b):1==a.a&&("function"==typeof d?e(d.call(void 0,a.b)):b(a.b))}catch(h){b(h)}}})}n.prototype.g=function(a){return this.c(void 0,a)};n.prototype.c=function(a,b){var c=this;return new n(function(d,e){c.f.push([a,b,d,e]);v(c)})};\nfunction w(a){return new n(function(b,c){function d(c){return function(d){h[c]=d;e+=1;e==a.length&&b(h)}}var e=0,h=[];0==a.length&&b(h);for(var k=0;k<a.length;k+=1)u(a[k]).c(d(k),c)})}function x(a){return new n(function(b,c){for(var d=0;d<a.length;d+=1)u(a[d]).c(b,c)})};window.Promise||(window.Promise=n,window.Promise.resolve=u,window.Promise.reject=t,window.Promise.race=x,window.Promise.all=w,window.Promise.prototype.then=n.prototype.c,window.Promise.prototype["catch"]=n.prototype.g);}());\n\n(function ...

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
news_blocks = soup.find_all('div', class_='page__body')

# %%
dates = list(map(lambda x: x.find_all('span', class_='post__time'), news_blocks))

# %%
headings = list(map(lambda x: x.find_all('h2', class_='post__title'), news_blocks))

# %%
all_titles = []
for heading in headings:
    for _ in heading:
        headings = _.find('a').get('href')
        all_titles.append(headings)
print(all_titles)
# Out:
# ['https://habr.com/ru/post/446488/', 'https://habr.com/ru/post/340302/', 'https://habr.com/ru/post/450834/', 'https://habr.com/ru/post/521646/', 'https://habr.com/ru/company/fetchee/blog/316558/', 'https://habr.com/ru/company/pt/blog/210772/', 'https://habr.com/ru/post/414221/', 'https://habr.com/ru/company/click/blog/465277/', 'https://habr.com/ru/post/121815/', 'https://habr.com/ru/post/253439/', 'https://habr.com/ru/post/252379/', 'https://habr.com/ru/post/444876/', 'https://habr.com/ru/post/349942/', 'https://habr.com/ru/post/504900/', 'https://habr.com/ru/post/505888/', 'https://habr.com/ru/post/262991/', 'https://habr.com/ru/post/169409/', 'https://habr.com/ru/post/60430/', 'https://habr.com/ru/post/127584/', 'https://habr.com/ru/post/273253/']

# %%
news = pd.DataFrame()

for title in all_titles:
    soup = BeautifulSoup(requests.get(title).text, 'html.parser')
    time.sleep(0.3)
    date = soup.find('span', class_='post__time').get('data-time_published')
    title = soup.find('span', class_='post__title-text').text
    row = {'дата': date, 'заголовок': title, 'ссылка': title}
    news = pd.concat([news, pd.DataFrame([row])]) 
news
# Out:
#                 дата                                          заголовок  \
# 0  2019-04-03T12:21Z  Правда про парсинг сайтов, или «все интернет-м...
# 0  2017-10-17T11:04Z  Парсинг сайтов: как с точки зрения закона выгл...
# 0  2019-05-07T11:51Z   Парсинг сайтов — а это вообще легально в России?
# 0  2020-10-01T14:17Z  Как выбрать решение для парсинга сайтов: класс...
# 0  2016-12-01T09:46Z  Пример использования Product API от Fetchee дл...
# 0  2016-03-03T13:39Z  Теория и практика парсинга исходников с помощь...
# 0  2018-06-18T20:42Z               Парсинг и работа с Codable в Swift 4
# 0  2019-08-28T11:12Z  Парсинг и анализ семантики для SEO: 5 бесплатн...
# 0  2011-06-14T15:24Z     Парсинг на Pуthon. Как собрать архив Голубятен
# 0  2015-03-18T14:52Z         Продвинутый парсинг веб-сайтов с Mechanize
# 0  2015-03-06T14:40Z                                Веб-парсинг на Ruby
# 0  2019-03-23T17:36Z  Искусство парсинга 2 или транслитерация собств...
# 0  2018-02-26T07:28Z  Парсинг telegram каналов для агрегатора контен...
# 0  2020-07-23T12:17Z  Как проанализировать рынок фотостудий с помощь...
# 0  2020-06-08T14:46Z  Парсинг YouTube, включая подгружаемые данные, ...
# 0  2015-07-19T12:27Z            Использование morph.io для веб-парсинга
# 0  2013-02-14T10:46Z  Парсинг сайтов-магазинов. Личный опыт и немног...
# 0  2009-05-25T17:15Z                         Еще о парсинге на Prolog'е
# 0  2011-09-02T10:37Z       Grab — python библиотека для парсинга сайтов
# 0  2015-12-16T08:45Z                Парсинг формул в 50 строк на Python
#
#                                               ссылка
# 0  Правда про парсинг сайтов, или «все интернет-м...
# 0  Парсинг сайтов: как с точки зрения закона выгл...
# 0   Парсинг сайтов — а это вообще легально в России?
# 0  Как выбрать решение для парсинга сайтов: класс...
# 0  Пример использования Product API от Fetchee дл...
# 0  Теория и практика парсинга исходников с помощь...
# 0               Парсинг и работа с Codable в Swift 4
# 0  Парсинг и анализ семантики для SEO: 5 бесплатн...
# 0     Парсинг на Pуthon. Как собрать архив Голубятен
# 0         Продвинутый парсинг веб-сайтов с Mechanize
# 0                                Веб-парсинг на Ruby
# 0  Искусство парсинга 2 или транслитерация собств...
# 0  Парсинг telegram каналов для агрегатора контен...
# 0  Как проанализировать рынок фотостудий с помощь...
# 0  Парсинг YouTube, включая подгружаемые данные, ...
# 0            Использование morph.io для веб-парсинга
# 0  Парсинг сайтов-магазинов. Личный опыт и немног...
# 0                         Еще о парсинге на Prolog'е
# 0       Grab — python библиотека для парсинга сайтов
# 0                Парсинг формул в 50 строк на Python

# %% [markdown]
# ### Дополнительная часть (необязательная)
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст_статьи>

# %% [markdown]
# ## Задание 2.
# ### Обязательная часть
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck. Список email-ов задаем переменной в начале кода:
# EMAIL = [xxx@x.ru, yyy@y.com]
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>
#
# Подсказка: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
import json

# %%
email = ['xxx@x.ru', 'yyy@y.com']
url = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'
params = {'emailAddresses': email}
headers = {'Vaar-Version' : '0', 'Vaar-Header-App-Product' : 'hackcheck-web-avast'}
req = requests.post(url, data = json.dumps(params), headers = headers)

# %%
dict_ = req.json()

# %%
list_email = pd.DataFrame()

# %%
for i,j in dict_.items():
      if i == 'summary':
        for email_, _ in dict_['summary'].items(): 
            list_ = _['breaches']
            for item in list_:
                date = (dict_['breaches'][str(item)]['publishDate'])
                source = (dict_['breaches'][str(item)]['site']) 
                description = (dict_['breaches'][str(item)]['description'])
                row = {'почта': email_, 'дата утечки': date, 'источник утечки': source, 'описание утечки': description}
                list_email = pd.concat([list_email, pd.DataFrame([row])])

# %%
list_email
# Out:
#        почта           дата утечки         источник утечки  \
# 0   xxx@x.ru  2019-03-28T00:00:00Z        verifications.io
# 0   xxx@x.ru  2020-05-21T00:00:00Z                  vk.com
# 0   xxx@x.ru  2017-02-14T00:00:00Z          parapa.mail.ru
# 0   xxx@x.ru  2016-10-29T00:00:00Z                  vk.com
# 0   xxx@x.ru  2016-10-21T00:00:00Z               adobe.com
# 0   xxx@x.ru  2017-02-14T00:00:00Z           cfire.mail.ru
# 0   xxx@x.ru  2017-01-31T00:00:00Z        cdprojektred.com
# 0   xxx@x.ru  2016-10-23T00:00:00Z               imesh.com
# 0  yyy@y.com  2019-03-28T00:00:00Z        verifications.io
# 0  yyy@y.com  2019-02-21T00:00:00Z        www.dangdang.com
# 0  yyy@y.com  2020-11-19T00:00:00Z               123rf.com
# 0  yyy@y.com  2020-01-03T00:00:00Z           azcentral.com
# 0  yyy@y.com  2020-05-28T00:00:00Z             wishbone.io
# 0  yyy@y.com  2017-11-04T00:00:00Z          myheritage.com
# 0  yyy@y.com  2017-12-01T00:00:00Z       creocommunity.com
# 0  yyy@y.com  2019-06-13T00:00:00Z               canva.com
# 0  yyy@y.com  2016-10-24T00:00:00Z             dropbox.com
# 0  yyy@y.com  2016-10-21T00:00:00Z            linkedin.com
# 0  yyy@y.com  2017-03-01T00:00:00Z            rayli.com.cn
# 0  yyy@y.com  2019-10-17T00:00:00Z               zynga.com
# 0  yyy@y.com  2019-07-11T00:00:00Z  medicaresupplement.com
# 0  yyy@y.com  2016-10-21T00:00:00Z               adobe.com
# 0  yyy@y.com  2018-02-18T00:00:00Z              netlog.com
# 0  yyy@y.com  2017-03-15T00:00:00Z          globalreach.eu
# 0  yyy@y.com  2016-10-23T00:00:00Z               imesh.com
# 0  yyy@y.com  2017-03-24T00:00:00Z               youku.com
#
#                                      описание утечки
# 0  Big data e-mail verification platform verifica...
# 0  At some time in 2020, the Russian social netwo...
# 0  In July and August 2016, two criminals execute...
# 0  Popular Russian social networking platform VKo...
# 0  In October of 2013, criminals penetrated Adobe...
# 0  In July and August of 2016, two criminals carr...
# 0  In March 2016, CDProjektRed.com.com's forum da...
# 0  In June 2016, a cache of over 51 million user ...
# 0  Big data e-mail verification platform verifica...
# 0  This is a list of email addresses only, and as...
# 0  In March 2020, the stock image agency 123RF wa...
# 0  At an unconfirmed date, online Arizona newspap...
# 0  In January 2020, the online poll website Wishb...
# 0  In October 2017, a customer database belonging...
# 0  At an unconfirmed date, Creo Community's user ...
# 0  In May 2019, graphic-design site Canva's datab...
# 0  Cloud storage company Dropbox suffered a major...
# 0  In 2012, online professional networking platfo...
# 0  On an unconfirmed date, Chinese gossip site Ra...
# 0  In September 2019, the game developer Zynga wa...
# 0  In May 2019, a security researcher discovered ...
# 0  In October of 2013, criminals penetrated Adobe...
# 0  Netlog (formerly known as Facebox and Bingbox)...
# 0  In 2016, Global Reach Technology's database wa...
# 0  In June 2016, a cache of over 51 million user ...
# 0  Youku is a large Chinese video content company...

# %% [markdown]
# ### Дополнительная часть (необязательная)
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods , вам поможет метод wall.get
#
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>
